# %%
# preprocess external dataset
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import folium

# %%
'''
Data from: https://www.census.gov/data/datasets/time-series/demo/popest/2010s-counties-total.html
'''


populationData = pd.read_csv("../Proj1data/nycCountyData.csv", index_col=False)

# %%
populationData = populationData.iloc[3:66]

# %%
populationData.columns = ['Geographical Area', 'Census', 'Estimates Base', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',]

# %%
populationData.set_index(populationData["Geographical Area"])
# Out:
#                                            Geographical Area      Census  \
# Geographical Area
# New York                                            New York  19,378,102
# .Albany County, New York            .Albany County, New York     304,204
# .Allegany County, New York        .Allegany County, New York      48,946
# .Bronx County, New York              .Bronx County, New York   1,385,108
# .Broome County, New York            .Broome County, New York     200,600
# ...                                                      ...         ...
# .Washington County, New York    .Washington County, New York      63,216
# .Wayne County, New York              .Wayne County, New York      93,772
# .Westchester County, New York  .Westchester County, New York     949,113
# .Wyoming County, New York          .Wyoming County, New York      42,155
# .Yates County, New York              .Yates County, New York      25,348
#
#                               Estimates Base        2010        2011  \
# ...

# %%
# Out:
# RangeIndex(start=3, stop=66, step=1)

# %%
print(populationData.head())
# Out:
#             Geographical Area      Census Estimates Base        2010  \
# 3                    New York  19,378,102     19,378,144  19,399,878
# 4    .Albany County, New York     304,204        304,208     304,086
# 5  .Allegany County, New York      48,946         48,923      48,971
# 6     .Bronx County, New York   1,385,108      1,384,580   1,387,298
# 7    .Broome County, New York     200,600        200,675     200,481
#
#          2011        2012        2013        2014        2015        2016  \
# 3  19,499,241  19,572,932  19,624,447  19,651,049  19,654,666  19,633,428
# 4     304,596     305,723     306,589     307,151     307,433     307,597
# 5      48,800      48,210      47,900      47,652      47,334      47,044
# 6   1,397,335   1,411,496   1,421,928   1,430,942   1,440,005   1,444,417
# 7     199,363     198,667     197,914     197,251     195,928     194,498
#
#          2017        2018        2019
# 3  19,589,572  19,530,351  19,453,561
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_13117/1723134005.py in <module>
# ----> 1 State_population = populationData.loc[0, 3:]
#       2 print(State_population)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# ...

# %%
State_population = populationData.iloc[0, 3:]
print(State_population)
# Out:
# 2010    19,399,878
# 2011    19,499,241
# 2012    19,572,932
# 2013    19,624,447
# 2014    19,651,049
# 2015    19,654,666
# 2016    19,633,428
# 2017    19,589,572
# 2018    19,530,351
# 2019    19,453,561
# Name: 3, dtype: object

# %%
'''
The five counties for NYC are Kings, Bronx, Richmond, Queens, and New York counties, 
(as seen on this website: https://www.ny.gov/counties)
'''
# find 5 counties
bronx = populationData.iloc[3, 3:]
print(bronx)
kings = populationData.iloc[24, 3:]
print(kings)
ny = populationData.iloc[31, 3:]
print(ny)
queens = populationData.iloc[41, 3:]
print(queens)
richmond = populationData.iloc[43, 3:]
print(richmond)

City_population = bronx + kings + ny + queens + richmond
print(City_population)
# Out:
# 2010    1,387,298
# 2011    1,397,335
# 2012    1,411,496
# 2013    1,421,928
# 2014    1,430,942
# 2015    1,440,005
# 2016    1,444,417
# 2017    1,440,625
# 2018    1,432,087
# 2019    1,418,207
# Name: 6, dtype: object
# 2010    2,509,828
# 2011    2,540,817
# 2012    2,568,450
# 2013    2,587,684
# 2014    2,601,513
# 2015    2,608,794
# 2016    2,608,423
# 2017    2,594,676
# 2018    2,578,074
# 2019    2,559,903
# Name: 27, dtype: object
# 2010    1,588,767
# 2011    1,608,293
# 2012    1,623,911
# 2013    1,627,491
# 2014    1,630,678
# 2015    1,636,063
# 2016    1,635,443
# 2017    1,630,698
# 2018    1,629,055
# 2019    1,628,706
# Name: 34, dtype: object
# 2010    2,234,701
# 2011    2,255,482
# 2012    2,272,222
# 2013    2,287,185
# 2014    2,298,736
# 2015    2,305,838
# 2016    2,306,830
# 2017    2,295,808
# 2018    2,274,605
# 2019    2,253,858
# Name: 44, dtype: object
# 2010    469,615
# 2011    471,021
# 2012    470,614
# 2013    471,803
# 2014    471,937
# ...
