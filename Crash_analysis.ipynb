# %%
# preprocess external dataset
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import folium

# %%
crash_data = pd.read_csv("../Proj1data/crash_data.csv")

# %%
print(crash_data['VEHICLE TYPE CODE 1'].value_counts())
print(crash_data['VEHICLE TYPE CODE 2'].value_counts())
print(crash_data['VEHICLE TYPE CODE 3'].value_counts())
# Out:
# Sedan                                  22781
# Station Wagon/Sport Utility Vehicle    19142
# Taxi                                    2494
# Pick-up Truck                           1475
# Box Truck                                974
#                                        ...
# REFG                                       1
# Bulk Agriculture                           1
# Hrse                                       1
# Snow                                       1
# COMMU                                      1
# Name: VEHICLE TYPE CODE 1, Length: 176, dtype: int64
# Sedan                                  16869
# Station Wagon/Sport Utility Vehicle    14950
# Taxi                                    1844
# Pick-up Truck                           1439
# Box Truck                               1150
#                                        ...
# NYC F                                      1
# tract                                      1
# SEMI                                       1
# Jeep                                       1
# Vanette                                    1
# Name: VEHICLE TYPE CODE 2, Length: 188, dtype: int64
# Sedan                                  1629
# Station Wagon/Sport Utility Vehicle    1272
# Taxi                                     91
# Pick-up Truck                            74
# Box Truck                                27
# Bus                                      17
# Tractor Truck Diesel                     13
# Van                                      12
# Bike                                      9
# Convertible                               5
# Tow Truck / Wrecker                       4
# Flat Bed                                  3
# Ambulance                                 3
# Stake or Rack                             2
# Motorcycle                                2
# Tractor Truck Gasoline                    2
# AMBUL                                     2
# Garbage or Refuse                         2
# TRAIL                                     1
# TRUCK                                     1
# van                                       1
# DIRT-                                     1
# Multi-Wheeled Vehicle                     1
# Motorscooter                              1
# Dump                                      1
# PK                                        1
# Moped                                     1
# 38AB-                                     1
# ambul                                     1
# scoot                                     1
# Name: VEHICLE TYPE CODE 3, dtype: int64

# %%
crash_data.size
# Out:
# 1468937

# %%
crash_data.head()
# Out:
#    CRASH DATE CRASH TIME BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0  02/01/2019      12:00     NaN       NaN       NaN        NaN
# 1  02/01/2019      16:40     NaN       NaN  40.69448  -73.81006
# 2  02/01/2019      17:45     NaN       NaN       NaN        NaN
# 3  02/01/2019      18:20     NaN       NaN       NaN        NaN
# 4  02/01/2019       8:40     NaN       NaN       NaN        NaN
#
#                 LOCATION                    ON STREET NAME CROSS STREET NAME  \
# 0                    NaN  ELLINGTON PARKWAY                  COLUMBUS AVENUE
# 1  (40.69448, -73.81006)  SANDERS PLACE                                  NaN
# 2                    NaN  TRIBOROUGH BRIDGE                              NaN
# 3                    NaN  1 avenue                            east 31 street
# 4                    NaN  QUEENS MIDTOWN TUNNEL                          NaN
#
#   OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0             NaN  ...                    Unspecified
# 1             NaN  ...                            NaN
# 2             NaN  ...                    Unspecified
# 3             NaN  ...                    Unspecified
# 4             NaN  ...                    Unspecified
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN       4074161
# 1                            NaN       4073145
# 2                            NaN       4073485
# 3                            NaN       4073140
# 4                            NaN       4073352
#
#                    VEHICLE TYPE CODE 1  VEHICLE TYPE CODE 2  \
# 0  Station Wagon/Sport Utility Vehicle                 Taxi
# 1                                Sedan                  NaN
# 2                                Sedan                  NaN
# 3  Station Wagon/Sport Utility Vehicle                Sedan
# 4                                  Van            Box Truck
#
#    VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]
